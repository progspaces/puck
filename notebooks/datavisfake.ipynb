# %%
UMAP	spidercolorectal	Uni	logreg
PCA	spiderskin	Uni2	xgboost
Rand	spiderbreast	HIBOU	mlp
	spiderthorax	DinoV2	
	sr386		
	kather100k

# %%
from itertools import product
projectors = ["UMAP", "PCA", "Rand"]
datasets = ["spidercolorectal","spiderskin","spiderbreast","spiderthorax","sr386","kather100k"]
encoders =[""]
classifiers = [""]
