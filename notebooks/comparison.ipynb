# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
def cleaner(path):
    print(path)
    df = pd.read_csv(path)
    print(df)
    df.columns =["name","time2","blobCount", "closeEnough", "closeCount4", "time", "points"]
    df[['images','palette', 'loc', 'height', 'set', "path"]] = df.name.str.split("/",expand=True)
    df = df.drop(["images", "name", "time2"], axis = 1)
    df["count4"] =(df["blobCount"] == 4)
    df_reordered = df.loc[:, ["palette", "loc", "height", "set", 'blobCount', 'closeEnough', 'count4', 'closeCount4', "time","points", "path"]] 
    df_reordered.to_csv(path[:-4] + "_cleaned.csv")

# %%
pathA = "../results/(9, 400, np.float64(0.8))_results_A.csv"
pathB = "../results/(9, 400, np.float64(0.8))_results_B.csv"

# %%
resultsA = pd.read_csv(pathA)
resultsB = pd.read_csv(pathB)

# %%
# cleaner(pathB)

# %%
random.seed(2026)
resultsA = pd.read_csv(pathA)
adjust  =ran_floats = [random.uniform(-.25,.25) for _ in range(480)]
resultsA["blobCount"] = resultsA["blobCount"] + adjust
sns.swarmplot(data=resultsA, x="set", y="blobCount", hue= "palette", alpha = .9, size = 3)
plt.title("A")
plt.grid()
plt.show()

# %%
random.seed(2026)
resultsB = pd.read_csv(pathB)
adjust  =ran_floats = [random.uniform(-.25,.25) for _ in range(480)]
resultsB["blobCount"] = resultsB["blobCount"] + adjust
sns.swarmplot(data=resultsB, x="set", y="blobCount", hue= "palette", alpha = .8, size = 3)
plt.title("B")
plt.grid()
plt.show()

# %%
resultsA=pd.read_csv(pathA)
resultsA["A or B"] = "A"
resultsB = pd.read_csv(pathB)
resultsB["A or B"] = "B"
jointResults = pd.concat([resultsA, resultsB])
sns.histplot(data= jointResults, x="blobCount", hue = "A or B", kde=True, binwidth= 1, alpha = .2,kde_kws= {"bw_adjust": 1.3}) 
plt.show()

# %%
# path0= "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/big_picture_0/otsu0.json_results.csv"
# path1= "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/big_picture/otsu1.jston_results.csv"
# otsu_0=pd.read_csv(path0)
# otsu_1 = pd.read_csv(path1)
# best60_0 = otsu_0.sort_values("1", ascending=False).head(60)
# best60_1 = otsu_1.sort_values("1", ascending=False).head(60)
# best60combos_0=list(best60_0["Unnamed: 0"])
# best60combos_1=list(best60_1["Unnamed: 0"])
# dictionaryTest = {"0": best60combos_0, "1":best60combos_1}
# best60combos = pd.DataFrame.from_dict(dictionaryTest)

# %%
# best60combos
# best60combos.to_csv("/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/best60combos.csv")

# %%
(resultsA["closeEnough"]).value_counts()
# Out:
# closeEnough
# True     445
# False     35
# Name: count, dtype: int64

# %%
(resultsA["count4"]).value_counts()
# Out:
# count4
# False    299
# True     181
# Name: count, dtype: int64

# %%
(resultsA["blobCount"]).value_counts()
# Out:
# blobCount
# 4    181
# 3    138
# 2     80
# 1     64
# 5     11
# 6      4
# 7      2
# Name: count, dtype: int64

# %%
resultsB["closeEnough"].value_counts()
# Out:
# closeEnough
# True     419
# False     61
# Name: count, dtype: int64

# %%
resultsB["count4"].value_counts()
# Out:
# count4
# False    351
# True     129
# Name: count, dtype: int64

# %%
resultsB["blobCount"].value_counts()
# Out:
# blobCount
# 3    178
# 4    129
# 2    118
# 1     37
# 5      9
# 0      7
# 6      2
# Name: count, dtype: int64

# %%
resultsB['closeCount4'].value_counts()
# Out:
# closeCount4
# False    369
# True     111
# Name: count, dtype: int64

# %%
# pathC = "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/try_results.csv"
# resultsC = pd.read_csv(pathC)
# # resultsC
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 pathC = "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/try_results.csv"
# ----> 2 resultsC = pd.read_csv(pathC)
#       3 resultsC
#
# ...

# %%
(resultsC["blobCount"]).value_counts()
# Out:
# blobCount
# 4    287
# 3    108
# 2     43
# 1     24
# 5      9
# 6      7
# 0      2
# Name: count, dtype: int64

# %%
resultsC['closeCount4'].value_counts()
# Out:
# closeCount4
# True     257
# False    223
# Name: count, dtype: int64

# %%
resultsC["closeEnough"].value_counts()
# Out:
# closeEnough
# True     422
# False     58
# Name: count, dtype: int64

# %%
pathD = "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv"
# cleaner(pathD)
resultsD = pd.read_csv(pathD)
resultsD
# Out:
# /Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv
#                                             Unnamed: 0  0      1      2  \
# 0    images/custom/davids/high/A/custom_davids_high...  4  False  False
# 1    images/custom/davids/high/A/custom_davids_high...  3  False  False
# 2    images/custom/davids/high/A/custom_davids_high...  4  False  False
# 3    images/custom/davids/high/A/custom_davids_high...  3   True  False
# 4    images/custom/davids/high/A/custom_davids_high...  3   True  False
# ..                                                 ... ..    ...    ...
# 475  images/dark/michaels/short/D/dark_michaels_sho...  4   True   True
# 476  images/dark/michaels/short/D/dark_michaels_sho...  4   True   True
# 477  images/dark/michaels/short/D/dark_michaels_sho...  4   True   True
# 478  images/dark/michaels/short/D/dark_michaels_sho...  4   True   True
# 479  images/dark/michaels/short/D/dark_michaels_sho...  4   True   True
#
# ...

# %%
resultsD['blobCount'].value_counts()
# Out:
# blobCount
# 3    158
# 2    138
# 4    130
# 1     36
# 5     10
# 0      7
# 6      1
# Name: count, dtype: int64

# %%
pathE = "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv"
# cleaner(pathE)
resultsE = pd.read_csv(pathE)
resultsE['blobCount'].value_counts()
# Out:
# /Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv
#                                             Unnamed: 0  0     1      2  \
# 0    images/custom/davids/high/A/custom_davids_high...  4  True   True
# 1    images/custom/davids/high/A/custom_davids_high...  5  True  False
# 2    images/custom/davids/high/A/custom_davids_high...  4  True   True
# 3    images/custom/davids/high/A/custom_davids_high...  4  True   True
# 4    images/custom/davids/high/A/custom_davids_high...  4  True   True
# ..                                                 ... ..   ...    ...
# 475  images/dark/michaels/short/D/dark_michaels_sho...  4  True   True
# 476  images/dark/michaels/short/D/dark_michaels_sho...  4  True   True
# 477  images/dark/michaels/short/D/dark_michaels_sho...  4  True   True
# 478  images/dark/michaels/short/D/dark_michaels_sho...  0  True  False
# 479  images/dark/michaels/short/D/dark_michaels_sho...  4  True   True
#
# ...

# %%
resultsE['closeCount4'].value_counts()
# Out:
# closeCount4
# True     322
# False    158
# Name: count, dtype: int64

# %%
# pathF = "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv"
# # cleaner(pathF)
# resultsF= pd.read_csv(pathF)
# resultsF['closeCount4'].value_counts()
# Out:
# /Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[169], line 2
#       1 pathF = "/Users/jdreiling/Desktop/puck/puck/src/puck/dotpipeline/pipeline_results/3/3/[9, 400, 0.8]_results.csv"
# ----> 2 cleaner(pathF)
#       3 resultsF= pd.read_csv(pathF)
#       4 resultsF['closeCount4'].value_counts()
#
# Cell In[134], line 3, in cleaner(path)
#       1 def cleaner(path):
#       2     print(path)
# ----> 3     df = pd.read_csv(path)
#       4     print(df)
#       5     df.columns =["name", "blobCount", "closeEnough", "closeCount4", "time", "points"]
#
# ...

# %%
pathPP = "../results/pipeline_results/ppMultiTest/3/paperPrograms_results.csv"
resultsPP= pd.read_csv(pathPP)
resultsPP['closeCount4'].value_counts()
# Out:
# closeCount4
# True     450
# False     30
# Name: count, dtype: int64

# %%
pathTiming= "../results/timing_per_binary_thresh_cleaned.csv"
resultsTiming= pd.read_csv(pathTiming)
resultsTiming['closeCount4'].value_counts()
# Out:
# closeCount4
# True     615
# False     50
# Name: count, dtype: int64

# %%
resultsTiming
resultsTiming["numberOfThreshChecks"] = [x[-1:] for x in resultsTiming["path"]]
def reset(x):
    x = int(x)
    if x < 5:
         return x+1
    elif x==5:
        return 10
    elif x==6:
        return 15
    else:
        print("AH")
        return x
resultsTiming["thresholdCount"] = resultsTiming["numberOfThreshChecks"].apply(reset)
resultsTiming.drop(["numberOfThreshChecks"], axis=1)
# Out:
#      Unnamed: 0 palette       loc height set  blobCount  closeEnough  count4  \
# 0             0  custom    davids   high   A          4         True    True
# 1             1  custom    davids   high   A          4         True    True
# 2             2  custom    davids   high   A          4         True    True
# 3             3  custom    davids   high   A          5         True   False
# 4             4  custom    davids   high   A          4         True    True
# ..          ...     ...       ...    ...  ..        ...          ...     ...
# 660         660    dark  michaels  short   D          4         True    True
# 661         661    dark  michaels  short   D          4         True    True
# 662         662    dark  michaels  short   D          4         True    True
# 663         663    dark  michaels  short   D          4         True    True
# 664         664    dark  michaels  short   D          4         True    True
#
# ...

# %%
##averages
averages = {}
print((resultsTiming.loc[resultsTiming["thresholdCount"]==1]))
time_1 = (resultsTiming.loc[resultsTiming["thresholdCount"]==1])["time"]
time_2 = (resultsTiming.loc[resultsTiming["thresholdCount"]==2])["time"]
time_3 = (resultsTiming.loc[resultsTiming["thresholdCount"]==3])["time"]
time_4 = (resultsTiming.loc[resultsTiming["thresholdCount"]==4])["time"]
time_5 = (resultsTiming.loc[resultsTiming["thresholdCount"]==5])["time"]
time_10 = (resultsTiming.loc[resultsTiming["thresholdCount"]==10])["time"]
time_15 = (resultsTiming.loc[resultsTiming["thresholdCount"]==15])["time"]

averages.update({1: np.average(time_1),
                 2: np.average(time_2),
                 3: np.average(time_3),
                 4: np.average(time_4),
                 5: np.average(time_5),
                 10: np.average(time_10), 
                 15: np.average(time_15)})
statsDF = pd.DataFrame.from_dict(averages,orient='index')
statsDF
# Out:
#      Unnamed: 0 palette       loc  height set  blobCount  closeEnough  count4  \
# 0             0  custom    davids    high   A          4         True    True
# 7             7  custom    davids    high   B          4         True    True
# 14           14  custom    davids    high   C          3         True   False
# 21           21  custom    davids    high   D          4         True    True
# 28           28  custom    davids  medium   A          4         True    True
# ..          ...     ...       ...     ...  ..        ...          ...     ...
# 630         630    dark  michaels  medium   D          4         True    True
# 637         637    dark  michaels   short   A          4         True    True
# 644         644    dark  michaels   short   B          4         True    True
# 651         651    dark  michaels   short   C          4         True    True
# 658         658    dark  michaels   short   D          4         True    True
#
# ...

# %%
statsDF["medians"] = [np.median(time_1),
        np.median(time_2),
        np.median(time_3),
        np.median(time_4),
        np.median(time_5),
        np.median(time_10),
        np.median(time_15)]
statsDF
# Out:
#            0   medians
# 1   0.111932  0.111277
# 2   0.117384  0.116817
# 3   0.124198  0.122530
# 4   0.132950  0.130701
# 5   0.136245  0.133735
# 10  0.165341  0.161258
# 15  0.224100  0.220351

# %%
closeCount4_1 = (resultsTiming.loc[resultsTiming["thresholdCount"]==1])["closeCount4"]
closeCount4_2 = (resultsTiming.loc[resultsTiming["thresholdCount"]==2])["closeCount4"]
closeCount4_3 = (resultsTiming.loc[resultsTiming["thresholdCount"]==3])["closeCount4"]
closeCount4_4 = (resultsTiming.loc[resultsTiming["thresholdCount"]==4])["closeCount4"]
closeCount4_5 = (resultsTiming.loc[resultsTiming["thresholdCount"]==5])["closeCount4"]
closeCount4_10 = (resultsTiming.loc[resultsTiming["thresholdCount"]==10])["closeCount4"]
closeCount4_15 = (resultsTiming.loc[resultsTiming["thresholdCount"]==15])["closeCount4"]

# %%
closeEnough_1 = (resultsTiming.loc[resultsTiming["thresholdCount"]==1])["closeEnough"]
closeEnough_2 = (resultsTiming.loc[resultsTiming["thresholdCount"]==2])["closeEnough"]
closeEnough_3 = (resultsTiming.loc[resultsTiming["thresholdCount"]==3])["closeEnough"]
closeEnough_4 = (resultsTiming.loc[resultsTiming["thresholdCount"]==4])["closeEnough"]
closeEnough_5 = (resultsTiming.loc[resultsTiming["thresholdCount"]==5])["closeEnough"]
closeEnough_10 = (resultsTiming.loc[resultsTiming["thresholdCount"]==10])["closeEnough"]
closeEnough_15 = (resultsTiming.loc[resultsTiming["thresholdCount"]==15])["closeEnough"]

# %%
statsDF["closeEnoughAccuracy"] = [(closeEnough_1).sum()/95,
                                (closeEnough_2).sum()/95,
                                (closeEnough_3).sum()/95,
                                (closeEnough_4).sum()/95,
                                (closeEnough_5).sum()/95,
                                (closeEnough_10).sum()/95,
                                (closeEnough_15).sum()/95]
statsDF
# Out:
#            0   medians  closeEnoughAccuracy
# 1   0.111932  0.111277             1.000000
# 2   0.117384  0.116817             1.000000
# 3   0.124198  0.122530             1.000000
# 4   0.132950  0.130701             1.000000
# 5   0.136245  0.133735             1.000000
# 10  0.165341  0.161258             1.000000
# 15  0.224100  0.220351             0.978947

# %%
statsDF["closeCount4Accuracy"] = [(closeCount4_1).sum()/95,
                                (closeCount4_2).sum()/95,
                                (closeCount4_3).sum()/95,
                                (closeCount4_4).sum()/95,
                                (closeCount4_5).sum()/95,
                                (closeCount4_10).sum()/95,
                                (closeCount4_15).sum()/95]
statsDF
# Out:
#            0   medians  closeEnoughAccuracy  closeCount4Accuracy
# 1   0.111932  0.111277             1.000000             0.873684
# 2   0.117384  0.116817             1.000000             0.936842
# 3   0.124198  0.122530             1.000000             0.957895
# 4   0.132950  0.130701             1.000000             0.936842
# 5   0.136245  0.133735             1.000000             0.957895
# 10  0.165341  0.161258             1.000000             0.947368
# 15  0.224100  0.220351             0.978947             0.863158

# %%
count4_1 = (resultsTiming.loc[resultsTiming["thresholdCount"]==1])["count4"]
count4_2 = (resultsTiming.loc[resultsTiming["thresholdCount"]==2])["count4"]
count4_3 = (resultsTiming.loc[resultsTiming["thresholdCount"]==3])["count4"]
count4_4 = (resultsTiming.loc[resultsTiming["thresholdCount"]==4])["count4"]
count4_5 = (resultsTiming.loc[resultsTiming["thresholdCount"]==5])["count4"]
count4_10 = (resultsTiming.loc[resultsTiming["thresholdCount"]==10])["count4"]
count4_15 = (resultsTiming.loc[resultsTiming["thresholdCount"]==15])["count4"]
statsDF["count4Accuracy"] = [(count4_1).sum()/95,
                                (count4_2).sum()/95,
                                (count4_3).sum()/95,
                                (count4_4).sum()/95,
                                (count4_5).sum()/95,
                                (count4_10).sum()/95,
                                (count4_15).sum()/95]
statsDF=statsDF.reset_index()
statsDF
# Out:
#    index         0   medians  closeEnoughAccuracy  closeCount4Accuracy  \
# 0      1  0.111932  0.111277             1.000000             0.873684
# 1      2  0.117384  0.116817             1.000000             0.936842
# 2      3  0.124198  0.122530             1.000000             0.957895
# 3      4  0.132950  0.130701             1.000000             0.936842
# 4      5  0.136245  0.133735             1.000000             0.957895
# 5     10  0.165341  0.161258             1.000000             0.947368
# 6     15  0.224100  0.220351             0.978947             0.863158
#
#    count4Accuracy
# 0        0.873684
# 1        0.936842
# 2        0.957895
# 3        0.936842
# 4        0.957895
# 5        0.947368
# 6        0.884211

# %%
statsDF
statsDF.columns =["threshcount", "average","medians","closeEnoughAcc", "closeCount4Acc", "count4Acc"]

# %%
statsDF["diffFrom1"] = statsDF["average"]-0.111932
statsDF
# Out:
#    threshcount   average   medians  closeEnoughAcc  closeCount4Acc  count4Acc  \
# 0            1  0.111932  0.111277        1.000000        0.873684   0.873684
# 1            2  0.117384  0.116817        1.000000        0.936842   0.936842
# 2            3  0.124198  0.122530        1.000000        0.957895   0.957895
# 3            4  0.132950  0.130701        1.000000        0.936842   0.936842
# 4            5  0.136245  0.133735        1.000000        0.957895   0.957895
# 5           10  0.165341  0.161258        1.000000        0.947368   0.947368
# 6           15  0.224100  0.220351        0.978947        0.863158   0.884211
#
#       diffFrom1
# 0 -4.035263e-07
# 1  5.452428e-03
# 2  1.226620e-02
# 3  2.101814e-02
# 4  2.431314e-02
# 5  5.340869e-02
# 6  1.121683e-01

# %%
# print(statsDF[["threshcount", "medians"]])
statsDFshort = statsDF[["threshcount", "average", "medians"]]

sns.lineplot(data=statsDF, x="threshcount", y="average",color = "green", alpha=.7)
sns.scatterplot(data=statsDF, x="threshcount", y="average", color = "green",alpha=.7)
plt.xlabel("Number of Thresholds Tested")
plt.ylabel("Average Time for Detection (sec)")
plt.yticks(np.arange(0, .3, step=.025))
plt.xticks(np.arange(1, 16, step=1))
plt.grid()

# %%
sns.lineplot(data=statsDF, x="threshcount", y="diffFrom1")
sns.scatterplot(data=statsDF, x="threshcount", y="diffFrom1")
plt.ylim([0, .3])
plt.grid()

# %%
sns.lineplot(data=statsDF, x="threshcount", y="medians")
sns.scatterplot(data=statsDF, x="threshcount", y="medians")
plt.ylim([0, .3])
plt.xticks(np.arange(0,16,1))
plt.grid()

# %%
sns.lineplot(data=statsDF, x="threshcount", y="closeCount4Acc")
sns.scatterplot(data=statsDF, x="threshcount", y="closeCount4Acc")
plt.ylim([.8, 1])
plt.xlabel("Number of Thresholds Tested")
plt.ylabel("Accuracy (Only 4 Dots and Close Enough)")
plt.xticks(np.arange(1,16,1))
plt.grid()

# %%
statsDF["timeFor1"]= np.repeat(0.111932,7)
statsDF["accFor1"] = np.repeat(0.873684,7)
statsDF["Bang For Your Buck, acc/.01secondincrease"] = (statsDF["closeCount4Acc"] -statsDF["closeCount4Acc"][0]) /((statsDF["average"] - statsDF["average"][0])/.01)
statsDF
# Out:
#    threshcount   average   medians  closeEnoughAcc  closeCount4Acc  count4Acc  \
# 0            1  0.111932  0.111277        1.000000        0.873684   0.873684
# 1            2  0.117384  0.116817        1.000000        0.936842   0.936842
# 2            3  0.124198  0.122530        1.000000        0.957895   0.957895
# 3            4  0.132950  0.130701        1.000000        0.936842   0.936842
# 4            5  0.136245  0.133735        1.000000        0.957895   0.957895
# 5           10  0.165341  0.161258        1.000000        0.947368   0.947368
# 6           15  0.224100  0.220351        0.978947        0.863158   0.884211
#
#       diffFrom1  closeCount4Accuracy  \
# 0 -4.035263e-07             0.873684
# 1  5.452428e-03             0.936842
# 2  1.226620e-02             0.957895
# 3  2.101814e-02             0.936842
# 4  2.431314e-02             0.957895
# 5  5.340869e-02             0.947368
# 6  1.121683e-01             0.863158
#
# ...

# %%
sns.lineplot(data=statsDF, x="threshcount", y="relativeAcc/Time", color = "orange" )
sns.scatterplot(data=statsDF, x="threshcount", y="relativeAcc/Time",color = "orange" )
plt.xticks(np.arange(0,16,1))
plt.grid()

# %%
(resultsA["closeEnough"]).value_counts()
# Out:
# closeEnough
# True     445
# False     35
# Name: count, dtype: int64

# %%
sns.histplot(data= resultsTiming, x="blobCount", multiple = "dodge", binwidth = .5, hue="thresholdCount",  palette=sns.color_palette("tab10")) 

plt.show()
# Out:
# /var/folders/mk/9_9tysr90mz2v8mfc415n5380000gn/T/ipykernel_50829/976879222.py:1: UserWarning: The palette list has more values (10) than needed (7), which may not be intended.
#   sns.histplot(data= resultsTiming, x="blobCount", multiple = "dodge", binwidth = .5, hue="thresholdCount",  palette=sns.color_palette("tab10"))
