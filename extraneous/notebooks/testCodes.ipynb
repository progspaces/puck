# %% [markdown]
# Create bounding boxes out of combinations of the palette and black as a starting point to give order to it.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %%
customPal = ["#261626" ,"#FBFAFA", "#FD1622" ,"#FE00FF",
 "#00FE16", "#0084FE", "#FEAA0D", "#DB4F89",
 "#EBFB26" ,"#00F8C4" ,"#B679D0" ,"#00D6FB",
 "#627C1C", "#A30DFB", "#A26649", "#D44D00",
 "#00847C", "#FFE69D" ]
# generated from the R code above

setOfEight = customPal[2:10]

# %%
darks = [ "#2E91E5" , "#E15F99" , "#1CA71C", "#FB0D0D" , "#DA16FF" ,"#B68100" ,"#750D86" ,"#EB663B" ]
setOfEight = darks
print(len(setOfEight))
# Out:
# 8

# %% [markdown]
# Let's make a couple of sets
#
# 0 1 2 3 4 5 6 7
#
# 0 3 5 setA
# 0 2 7 setB
# 4 6 5 setC
# 5 5 5 setD
# 3 0 2 setE
# 1 6 4 setF
# 1 4 6 setG
# 2 0 3 setH

# %%
setA = [ "#000000", setOfEight[0], setOfEight[3], setOfEight[5]]
setB = [ "#000000", setOfEight[0], setOfEight[2], setOfEight[7]]
setC = [ "#000000", setOfEight[4], setOfEight[6], setOfEight[5]]
setD = [ "#000000", setOfEight[5], setOfEight[5], setOfEight[5]]
setE = [ "#000000", setOfEight[3], setOfEight[0], setOfEight[2]]
setF = [ "#000000", setOfEight[1], setOfEight[6], setOfEight[4]]
setG = [ "#000000", setOfEight[1], setOfEight[4], setOfEight[6]]
setH = [ "#000000", setOfEight[2], setOfEight[0], setOfEight[3]]

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
scaler = 72*cm2inch
s = np.tile([(2*scaler)**2], 4)
scatter = ax.scatter([1,1,25.5,25.5], [1,17,1,17], c=setD, s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('setDarkD1.png', dpi=1000)
fig.savefig('setDarkD1.pdf')

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
scaler = 72*cm2inch
s = np.tile([(1*scaler)**2], 4)
scatter = ax.scatter([1,1,20,20], [1,17,1,17], c=setD, s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('setDarkD.png', dpi=1000)
fig.savefig('setDarkD.pdf')

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
scaler = 72*cm2inch
s = np.tile([(2*scaler)**2], 4)
scatter = ax.scatter([1.5,1.5,20,20], [1.5,15,1.5,15], c=setC, s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('setC3.png', dpi=1000)
fig.savefig('setC3.pdf')

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
scaler = 72*cm2inch
s = np.tile([(1*scaler)**2], 4)
scatter = ax.scatter([1,1,16,16], [1,14,1,14], c=setD, s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('setD.png', dpi=1000)
fig.savefig('setD.pdf')

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
scaler = 72*cm2inch
s = np.tile([(2*scaler)**2], 8)
scatter = ax.scatter([1.5,1.5,11.5,11.5,15,15,25,25], [1.5,17,1.5,17,1.5,17,1.5,17], c=np.concat((setE,setH)), s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('setEF2.png', dpi=1000)
fig.savefig('setEF2.pdf')

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
scaler = 72*cm2inch
s = np.tile([(1*scaler)**2], 8)
scatter = ax.scatter([.75,.75,11.75,11.75,14,14,26,26], [1,17,1,17,1,17,1,17], c=np.concat((setG,setH)), s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('setGH2.png', dpi=1000)
fig.savefig('setGH2.pdf')
