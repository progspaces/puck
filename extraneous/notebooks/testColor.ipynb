# %% [markdown]
# Generate a series of dots, of different sizes, seperated by 1 cm, to see if the camera can pick up the palette, and how to threshold it

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# R code to generate Palette
# library(Polychrome)
#
# set.seed(82000)
# N = 2+16
# seedcolors = c("#000000", "#FFFFFF")
# range = c(0,1000)
# ylim=c(0, 180)
#
# ours = createPalette(N, seedcolors, range=range)
# theirs = palette36.colors(n=N)
#
# print(ours)
# print(theirs)
#
# #layout(matrix(c(1,2), ncol=2))
#
# ourDists = plotDistances(ours, ylim=ylim)
# abline(h = 40)
# theirDists = plotDistances(theirs, ylim=ylim)
# abline(h = 40)
#
# swatch(ours)
# swatch(ourDists$colors)
# swatch(theirDists$colors)

# %%
customPal = ["#261626" ,"#FBFAFA", "#FD1622" ,"#FE00FF",
 "#00FE16", "#0084FE", "#FEAA0D", "#DB4F89",
 "#EBFB26" ,"#00F8C4" ,"#B679D0" ,"#00D6FB",
 "#627C1C", "#A30DFB", "#A26649", "#D44D00",
 "#00847C", "#FFE69D" ]
# generated from the R code above

setOfEight = customPal[2:10] # Grab the first 8 that aren't white and black
setTriple = np.repeat(setOfEight,3) # Triple them for testing r = 1cm, .75cm, and .5cm
# Out:
# 8
# ['#FD1622' '#FD1622' '#FD1622' '#FE00FF' '#FE00FF' '#FE00FF' '#00FE16'
#  '#00FE16' '#00FE16' '#0084FE' '#0084FE' '#0084FE' '#FEAA0D' '#FEAA0D'
#  '#FEAA0D' '#DB4F89' '#DB4F89' '#DB4F89' '#EBFB26' '#EBFB26' '#EBFB26'
#  '#00F8C4' '#00F8C4' '#00F8C4']

# %%
def palTriplCombin(pal1,pal2,pal3):
    return np.concat((np.repeat(pal1,3), np.repeat(pal2,3), np.repeat(pal3,3)))

darkCarter1 = palTriplCombin(darkPal,greyBlackPal1,carterPal)
customKelly2 = palTriplCombin(customPal,greyBlackPal2,kellyPal)

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
x=np.linspace(1, 25, 9,)
y=np.linspace(1, 16, 6, )
coords = np.array(np.meshgrid(x,y)).T.reshape(-1, 2)
xnew = [(c[0]) for c in coords][:24]
ynew = [(c[1]) for c in coords][:24]
scaler = 72*cm2inch
s = np.tile([(2*scaler)**2, (1.5*scaler)**2, (1*scaler)**2], 8)
scatter = ax.scatter(xnew, ynew, c=setTriple, s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('A4_grid_cm_test3.png', dpi=1000)
fig.savefig('tA4_grid_cm_test3.pdf')

# %%
setwBlack = np.concat((setOfEight, ["#000000"]))

# %%
# Source - https://stackoverflow.com/a
# Posted by Mahmoud, modified by community. See post 'Timeline' for change history
# Retrieved 2025-11-20, License - CC BY-SA 4.0

# This example fits a4 paper with 5mm margin printers

# figure settings
figure_width = 28.7 # cm
figure_height = 20 # cm
left_right_margin = 1 # cm
top_bottom_margin = 1 # cm
# standard a4 paper is 21 cm x 29.7cm

# Don't change
left   = left_right_margin / figure_width # Percentage from height
bottom = top_bottom_margin / figure_height # Percentage from height
width  = 1 - left*2
height = 1 - bottom*2
cm2inch = 1/2.54 # inch per cm

# specifying the width and the height of the box in inches
fig = plt.figure(figsize=(figure_width*cm2inch,figure_height*cm2inch))
ax = fig.add_axes((left, bottom, width, height))

# limits settings (important)
plt.xlim(0, figure_width * width)
plt.ylim(0, figure_height * height)

# # Ticks settings
# ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.xaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))
# ax.yaxis.set_major_locator(mpl.ticker.MultipleLocator(5))
# ax.yaxis.set_minor_locator(mpl.ticker.MultipleLocator(1))

# # Grid settings
# ax.grid(color="gray", which="both", linestyle=':', linewidth=0.5)




# your Plot (consider above limits)
x=np.linspace(4, 23, 5,)
y=np.linspace(3, 14, 3, )
coords = np.array(np.meshgrid(x,y)).T.reshape(-1, 2)
xnew = [(c[0]) for c in coords][:9]
ynew = [(c[1]) for c in coords][:9]
scaler = 72*cm2inch
s = np.tile([(1*scaler)**2], 9)
scatter = ax.scatter(xnew, ynew, c=setwBlack, s=s)

plt.axis('off')

# save figure ( printing png file had better resolution, pdf was lighter and better on screen)
plt.show()
fig.savefig('A4_grid_cm_test4.png', dpi=1000)
fig.savefig('tA4_grid_cm_test4.pdf')
