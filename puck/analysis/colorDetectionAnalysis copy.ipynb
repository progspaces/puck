# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats
import itertools 
import puck.experiments.permutation_guessing as pg

# %%
results_csv = pd.read_csv("../output/program_recognition_results_custom.csv")
results_csv = results_csv.drop("Unnamed: 0", axis=1)
results_csv
# Out:
#     key                                               path found_perm  \
# 0     a  ../puck/data/images_copy/custom/michaels/high/...        afd
# 1     a  ../puck/data/images_copy/custom/michaels/high/...        afd
# 2     a  ../puck/data/images_copy/custom/michaels/high/...        abd
# 3     a  ../puck/data/images_copy/custom/michaels/high/...        efd
# 4     a  ../puck/data/images_copy/custom/michaels/high/...        afd
# ..   ..                                                ...        ...
# 235   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 236   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 237   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 238   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 239   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
#
#     true_perm  correct  overlap
# 0         afd     True        3
# 1         afd     True        3
# 2         afd    False        2
# 3         afd    False        2
# 4         afd     True        3
# ..        ...      ...      ...
# 235       fff     True        3
# 236       fff     True        3
# 237       fff     True        3
# 238       fff     True        3
# 239       fff     True        3
#
# [240 rows x 6 columns]

# %%
sns.histplot(data= results_csv, x = "key",hue="overlap",multiple="dodge", shrink=.8,palette= sns.color_palette("Set2")[:4])
plt.title("Count of Overlaps per Permutation Key")
# Out:
# Text(0.5, 1.0, 'Count of Overlaps per Permutation Key')

# %%
results_csv_c = results_csv[results_csv["key"] == "c"]
print(results_csv_c["true_perm"].values[0])
results_csv_c["found_perm"].value_counts()
# Out:
# efg
# found_perm
# efg    38
# ebg    18
# gce     2
# efe     1
# ece     1
# Name: count, dtype: int64

# %%
results_csv_d = results_csv[results_csv["key"] == "d"]
print(results_csv_d["true_perm"].values[0])
results_csv_d["found_perm"].value_counts()
# Out:
# fff
# found_perm
# fff    46
# fbf     4
# bff     3
# bbf     2
# ffa     2
# ffb     1
# faf     1
# aff     1
# Name: count, dtype: int64

# %% [markdown]
# "#FE00FF",b
# "#DB4F89",f
#
# It frequently seems to get b and f confused.

# %%
results_csv_d = results_csv[results_csv["key"] == "d"]
print(results_csv_d["true_perm"].values[0])
results_csv_d["found_perm"].value_counts()
# Out:
# fff
# found_perm
# fff    46
# fbf     4
# bff     3
# bbf     2
# ffa     2
# ffb     1
# faf     1
# aff     1
# Name: count, dtype: int64

# %%
acc_dict = {}
for k in ['a','b','c', 'd']:
    key_selection =results_csv[results_csv["key"] == k]
    accuracy = round((sum(key_selection["correct"])/len(key_selection["correct"])),3)
    acc_dict.update({k: accuracy})

acc_dict
# Out:
# {'a': 0.867, 'b': 0.9, 'c': 0.633, 'd': 0.767}

# %%
close_dict = {}
for k in ['a','b','c', 'd']:
    key_selection =results_csv[results_csv["key"] == k]
    close = key_selection[(key_selection["overlap"]).astype(int) >= 2]
    close_acc = round((len(close)/len(key_selection["overlap"])),3)
    close_dict.update({k: close_acc})

close_dict
# Out:
# {'a': 0.967, 'b': 1.0, 'c': 0.95, 'd': 0.967}

# %%
def path_cutter(df):
    df["path2"] = df["path"].str.slice(len("../puck/data/images_copy/custom/"),len(df["path"]))
    print(df["path2"])
    df[['loc','height', 'perm', 'path']] = df.path2.str.split("/",expand=True)
    df = df.drop(["path2"], axis=1)

# %%
results_csv
# Out:
#     key                                               path found_perm  \
# 0     a  ../puck/data/images_copy/custom/michaels/high/...        afd
# 1     a  ../puck/data/images_copy/custom/michaels/high/...        afd
# 2     a  ../puck/data/images_copy/custom/michaels/high/...        abd
# 3     a  ../puck/data/images_copy/custom/michaels/high/...        efd
# 4     a  ../puck/data/images_copy/custom/michaels/high/...        afd
# ..   ..                                                ...        ...
# 235   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 236   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 237   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 238   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
# 239   d  ../puck/data/images_copy/custom/jack_cole/medi...        fff
#
#     true_perm  correct  overlap  \
# 0         afd     True        3
# 1         afd     True        3
# 2         afd    False        2
# 3         afd    False        2
# 4         afd     True        3
# ..        ...      ...      ...
# 235       fff     True        3
# 236       fff     True        3
# 237       fff     True        3
# 238       fff     True        3
# 239       fff     True        3
#
#                                                  path2
# 0        /michaels/high/A/custom_michaels_high_A_3.jpg
# 1        /michaels/high/A/custom_michaels_high_A_2.jpg
# 2        /michaels/high/A/custom_michaels_high_A_0.jpg
# 3        /michaels/high/A/custom_michaels_high_A_1.jpg
# 4        /michaels/high/A/custom_michaels_high_A_4.jpg
# ..                                                 ...
# 235  /jack_cole/medium/D/custom_jack_cole_medium_D_...
# 236  /jack_cole/medium/D/custom_jack_cole_medium_D_...
# 237  /jack_cole/medium/D/custom_jack_cole_medium_D_...
# 238  /jack_cole/medium/D/custom_jack_cole_medium_D_...
# 239  /jack_cole/medium/D/custom_jack_cole_medium_D_...
#
# [240 rows x 7 columns]

# %%
path_cutter(results_csv)
results_csv = results_csv.drop(["path2"], axis=1)
# Out:
# 0           michaels/high/A/custom_michaels_high_A_3.jpg
# 1           michaels/high/A/custom_michaels_high_A_2.jpg
# 2           michaels/high/A/custom_michaels_high_A_0.jpg
# 3           michaels/high/A/custom_michaels_high_A_1.jpg
# 4           michaels/high/A/custom_michaels_high_A_4.jpg
#                              ...
# 235    jack_cole/medium/D/custom_jack_cole_medium_D_4...
# 236    jack_cole/medium/D/custom_jack_cole_medium_D_2...
# 237    jack_cole/medium/D/custom_jack_cole_medium_D_3...
# 238    jack_cole/medium/D/custom_jack_cole_medium_D_1...
# 239    jack_cole/medium/D/custom_jack_cole_medium_D_0...
# Name: path2, Length: 240, dtype: object

# %%
results_csv_c = results_csv[results_csv["key"] == "c"]
results_csv_c
# Out:
#     key                              path found_perm true_perm  correct  \
# 120   c      custom_michaels_high_C_1.jpg        efg       efg     True
# 121   c      custom_michaels_high_C_0.jpg        efg       efg     True
# 122   c      custom_michaels_high_C_2.jpg        efg       efg     True
# 123   c      custom_michaels_high_C_3.jpg        efg       efg     True
# 124   c      custom_michaels_high_C_4.jpg        efg       efg     True
# 125   c     custom_michaels_short_C_1.jpg        efg       efg     True
# 126   c     custom_michaels_short_C_0.jpg        efg       efg     True
# 127   c     custom_michaels_short_C_2.jpg        efg       efg     True
# 128   c     custom_michaels_short_C_3.jpg        ebg       efg    False
# 129   c     custom_michaels_short_C_4.jpg        efe       efg    False
# 130   c    custom_michaels_medium_C_4.jpg        ebg       efg    False
# 131   c    custom_michaels_medium_C_3.jpg        ebg       efg    False
# 132   c    custom_michaels_medium_C_2.jpg        ebg       efg    False
# 133   c    custom_michaels_medium_C_0.jpg        ebg       efg    False
# 134   c    custom_michaels_medium_C_1.jpg        ebg       efg    False
# 135   c        custom_davids_high_C_4.jpg        efg       efg     True
# 136   c        custom_davids_high_C_0.jpg        efg       efg     True
# 137   c        custom_davids_high_C_1.jpg        ebg       efg    False
# 138   c        custom_davids_high_C_3.jpg        efg       efg     True
# 139   c        custom_davids_high_C_2.jpg        ebg       efg    False
# 140   c       custom_davids_short_C_4.jpg        ebg       efg    False
# 141   c       custom_davids_short_C_0.jpg        gce       efg    False
# 142   c       custom_davids_short_C_1.jpg        gce       efg    False
# 143   c       custom_davids_short_C_3.jpg        ece       efg    False
# 144   c       custom_davids_short_C_2.jpg        efg       efg     True
# 145   c      custom_davids_medium_C_0.jpg        efg       efg     True
# 146   c      custom_davids_medium_C_1.jpg        efg       efg     True
# 147   c      custom_davids_medium_C_3.jpg        ebg       efg    False
# 148   c      custom_davids_medium_C_2.jpg        efg       efg     True
# 149   c      custom_davids_medium_C_4.jpg        ebg       efg    False
# 150   c    custom_john_honey_high_C_1.jpg        efg       efg     True
# 151   c    custom_john_honey_high_C_0.jpg        efg       efg     True
# 152   c    custom_john_honey_high_C_2.jpg        efg       efg     True
# 153   c    custom_john_honey_high_C_3.jpg        ebg       efg    False
# 154   c    custom_john_honey_high_C_4.jpg        efg       efg     True
# 155   c   custom_john_honey_short_C_3.jpg        efg       efg     True
# 156   c   custom_john_honey_short_C_2.jpg        efg       efg     True
# 157   c   custom_john_honey_short_C_0.jpg        efg       efg     True
# 158   c   custom_john_honey_short_C_1.jpg        efg       efg     True
# 159   c   custom_john_honey_short_C_4.jpg        efg       efg     True
# 160   c  custom_john_honey_medium_C_4.jpg        efg       efg     True
# 161   c  custom_john_honey_medium_C_0.jpg        efg       efg     True
# 162   c  custom_john_honey_medium_C_1.jpg        efg       efg     True
# 163   c  custom_john_honey_medium_C_3.jpg        efg       efg     True
# 164   c  custom_john_honey_medium_C_2.jpg        efg       efg     True
# 165   c     custom_jack_cole_high_C_4.jpg        efg       efg     True
# 166   c     custom_jack_cole_high_C_3.jpg        ebg       efg    False
# 167   c     custom_jack_cole_high_C_2.jpg        efg       efg     True
# 168   c     custom_jack_cole_high_C_0.jpg        efg       efg     True
# 169   c     custom_jack_cole_high_C_1.jpg        efg       efg     True
# 170   c    custom_jack_cole_short_C_4.jpg        efg       efg     True
# 171   c    custom_jack_cole_short_C_3.jpg        efg       efg     True
# 172   c    custom_jack_cole_short_C_2.jpg        efg       efg     True
# 173   c    custom_jack_cole_short_C_0.jpg        efg       efg     True
# 174   c    custom_jack_cole_short_C_1.jpg        ebg       efg    False
# 175   c   custom_jack_cole_medium_C_1.jpg        ebg       efg    False
# 176   c   custom_jack_cole_medium_C_0.jpg        ebg       efg    False
# 177   c   custom_jack_cole_medium_C_2.jpg        ebg       efg    False
# 178   c   custom_jack_cole_medium_C_3.jpg        efg       efg     True
# 179   c   custom_jack_cole_medium_C_4.jpg        ebg       efg    False
#
#      overlap         loc  height perm
# 120        3    michaels    high    C
# 121        3    michaels    high    C
# 122        3    michaels    high    C
# 123        3    michaels    high    C
# 124        3    michaels    high    C
# 125        3    michaels   short    C
# 126        3    michaels   short    C
# 127        3    michaels   short    C
# 128        2    michaels   short    C
# 129        2    michaels   short    C
# 130        2    michaels  medium    C
# 131        2    michaels  medium    C
# 132        2    michaels  medium    C
# 133        2    michaels  medium    C
# 134        2    michaels  medium    C
# 135        3      davids    high    C
# 136        3      davids    high    C
# 137        2      davids    high    C
# 138        3      davids    high    C
# 139        2      davids    high    C
# 140        2      davids   short    C
# 141        0      davids   short    C
# 142        0      davids   short    C
# 143        1      davids   short    C
# 144        3      davids   short    C
# 145        3      davids  medium    C
# 146        3      davids  medium    C
# 147        2      davids  medium    C
# 148        3      davids  medium    C
# 149        2      davids  medium    C
# 150        3  john_honey    high    C
# 151        3  john_honey    high    C
# 152        3  john_honey    high    C
# 153        2  john_honey    high    C
# 154        3  john_honey    high    C
# 155        3  john_honey   short    C
# 156        3  john_honey   short    C
# 157        3  john_honey   short    C
# 158        3  john_honey   short    C
# 159        3  john_honey   short    C
# 160        3  john_honey  medium    C
# 161        3  john_honey  medium    C
# 162        3  john_honey  medium    C
# 163        3  john_honey  medium    C
# 164        3  john_honey  medium    C
# 165        3   jack_cole    high    C
# 166        2   jack_cole    high    C
# 167        3   jack_cole    high    C
# 168        3   jack_cole    high    C
# 169        3   jack_cole    high    C
# 170        3   jack_cole   short    C
# 171        3   jack_cole   short    C
# 172        3   jack_cole   short    C
# 173        3   jack_cole   short    C
# 174        2   jack_cole   short    C
# 175        2   jack_cole  medium    C
# 176        2   jack_cole  medium    C
# 177        2   jack_cole  medium    C
# 178        3   jack_cole  medium    C
# 179        2   jack_cole  medium    C

# %%
def pivot_creator(df:pd.DataFrame):
    entries = []
    for height, loc, in itertools.product(df["height"].unique(), df["loc"].unique()):
        selection = df[(df["height"] == height) & (df["loc"] == loc)]
        overlap_avg = stats.mean(selection["overlap"])
        entries.append({"height": height, "loc": loc, "overlap_avg": overlap_avg})
    return pd.DataFrame(entries, columns=["height", "loc", "overlap_avg"])

# %%
pivot_df = pivot_creator(results_csv_c)
results_c_pivot = (pivot_df.pivot(index="loc", columns="height", values="overlap_avg"))
sns.heatmap(results_c_pivot, annot=True, cmap=sns.color_palette("crest", as_cmap=True))
# Out:
# <Axes: xlabel='height', ylabel='loc'>

# %%
results_csv_c_low= results_csv_c[results_csv_c["height"] == "short"]
results_csv_c_low["found_perm"].value_counts()
# Out:
# found_perm
# efg    13
# ebg     3
# gce     2
# efe     1
# ece     1
# Name: count, dtype: int64

# %%
results_dark_csv = pd.read_csv("../results/program_recognition_results_dark.csv")
results_dark_csv = results_dark_csv.drop("Unnamed: 0", axis=1)
results_dark_csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 results_dark_csv = pd.read_csv("../results/program_recognition_results_dark.csv")
#       2 results_dark_csv = results_dark_csv.drop("Unnamed: 0", axis=1)
#       3 results_dark_csv
#
# File ~/Desktop/puck/puck/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/puck/puck/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/puck/puck/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/puck/puck/.venv/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/puck/puck/.venv/lib/python3.13/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/program_recognition_results_dark.csv'

# %%
sns.histplot(data= results_dark_csv, x = "key",hue="overlap",multiple="dodge", shrink=.8,palette= sns.color_palette("Set2")[:4])
plt.title("Count of Overlaps per Permutation Key")
# Out:
# Text(0.5, 1.0, 'Count of Overlaps per Permutation Key')

# %%
path_cutter(results_dark_csv)
results_dark_csv = results_dark_csv.drop(["path2"], axis=1)

# %%
results_dark_csv
# Out:
#     key                           path found_perm true_perm  correct  overlap  \
# 0     a     dark_michaels_high_A_1.jpg        afd       afd     True        3
# 1     a     dark_michaels_high_A_0.jpg        ahd       afd    False        2
# 2     a     dark_michaels_high_A_2.jpg        ahd       afd    False        2
# 3     a     dark_michaels_high_A_3.jpg        afd       afd     True        3
# 4     a     dark_michaels_high_A_4.jpg        afd       afd     True        3
# ..   ..                            ...        ...       ...      ...      ...
# 235   d  dark_jack_cole_medium_D_1.jpg        fhh       fff    False        1
# 236   d  dark_jack_cole_medium_D_0.jpg        fff       fff     True        3
# 237   d  dark_jack_cole_medium_D_2.jpg        hhh       fff    False        0
# 238   d  dark_jack_cole_medium_D_3.jpg        fhf       fff    False        2
# 239   d  dark_jack_cole_medium_D_4.jpg        fff       fff     True        3
#
#          loc  height perm
# 0     chaels    high    A
# 1     chaels    high    A
# 2     chaels    high    A
# 3     chaels    high    A
# 4     chaels    high    A
# ..       ...     ...  ...
# 235  ck_cole  medium    D
# 236  ck_cole  medium    D
# 237  ck_cole  medium    D
# 238  ck_cole  medium    D
# 239  ck_cole  medium    D
#
# [240 rows x 9 columns]

# %%
results_dark_csv_c = results_dark_csv[results_dark_csv["key"] == "c"]
results_dark_csv_b = results_dark_csv[results_dark_csv["key"] == "b"]
results_dark_csv_d = results_dark_csv[results_dark_csv["key"] == "d"]

# %%
print(results_dark_csv_c["true_perm"].values[0])
results_dark_csv_c["found_perm"].value_counts()
# Out:
# ebg
# found_perm
# gfg    18
# ghg    18
# efg    11
# efe     4
# ggh     4
# bfg     3
# ggf     2
# Name: count, dtype: int64

# %%
print(results_dark_csv_b["true_perm"].values[0])
results_dark_csv_b["found_perm"].value_counts()
# Out:
# ahc
# found_perm
# adc    26
# ahc    18
# adg    14
# gdg     1
# gdc     1
# Name: count, dtype: int64

# %%
print(results_dark_csv_d["true_perm"].values[0])
results_dark_csv_d["found_perm"].value_counts()
# Out:
# fff
# found_perm
# fff    40
# ffh    10
# fhf     3
# hhh     3
# fhh     3
# hfh     1
# Name: count, dtype: int64

# %%
acc_dict = {}
for k in ['a','b','c', 'd']:
    key_selection =results_dark_csv[results_dark_csv["key"] == k]
    accuracy = round((sum(key_selection["correct"])/len(key_selection["correct"])),3)
    acc_dict.update({k: accuracy})

acc_dict
# Out:
# {'a': 0.7, 'b': 0.3, 'c': 0.0, 'd': 0.667}

# %%
close_dict = {}
for k in ['a','b','c', 'd']:
    key_selection =results_dark_csv[results_dark_csv["key"] == k]
    close = key_selection[(key_selection["overlap"]).astype(int) >= 2]
    close_acc = round((len(close)/len(key_selection["overlap"])),3)
    close_dict.update({k: close_acc})

close_dict
# Out:
# {'a': 0.967, 'b': 0.733, 'c': 0.183, 'd': 0.883}

# %%
pivot_df_dark = pivot_creator(results_dark_csv_c)
results_dark_c_pivot = (pivot_df_dark.pivot(index="loc", columns="height", values="overlap_avg"))
sns.heatmap(results_dark_c_pivot, annot=True, cmap=sns.color_palette("crest", as_cmap=True))
# Out:
# <Axes: xlabel='height', ylabel='loc'>

# %%
pivot_df_dark_b = pivot_creator(results_dark_csv_b)
results_dark_b_pivot = (pivot_df_dark_b.pivot(index="loc", columns="height", values="overlap_avg"))
sns.heatmap(results_dark_b_pivot, annot=True, cmap=sns.color_palette("crest", as_cmap=True))
# Out:
# <Axes: xlabel='height', ylabel='loc'>
