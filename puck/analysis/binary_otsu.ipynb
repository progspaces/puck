# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stats
import puck.experiments.best_thresholding.binary_otsu as bo

# %%
output_file_dict = bo.main(
    adjustment_on = True
    cli_printout = False
    )
# Out:
# <class 'dict'>
#   0%|          | 0/60 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 output_file_dict = bo.main(
#       2     input_path="../data/images_copy",
#       3     output_overall = "../output/experimental_results/",
#       4     output_timing ="../output/timing_results",
#       5     ground_truth="../data/annotations/annotations.json",
#       6     cli_printout = False
#       7     )
#
# File ~/Desktop/puck/puck/puck/experiments/best_thresholding/binary_otsu.py:145, in main(input_path, output_overall, output_results, output_bp, output_timing, ground_truth, cli_printout)
#     143     print(type(list_of_file_datas[1]))
#     144     list_of_results_paths = [results_path]* len(generatored_pipelines)
# --> 145     for name, result in tqdm(pool.map(pipelineTests, zip(generatored_pipelines, list_of_choices,list_of_input_paths,list_of_results_paths,list_of_file_datas)), total=len(generatored_pipelines)):
#     146         pipeline_list_dict.update({name:result})
#     148 # ensure that output directory exists for the big picture
#
# File ~/Desktop/puck/puck/.venv/lib/python3.13/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/.local/share/uv/python/cpython-3.13.11-macos-aarch64-none/lib/python3.13/threading.py:359, in Condition.wait(self, timeout)
#     357 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     358     if timeout is None:
# --> 359         waiter.acquire()
#     360         gotit = True
#     361     else:
#
# KeyboardInterrupt:

# %%
otsu_csv = pd.read_csv("../results/big_picture_0/otsu0.json_results.csv")
otsu_csv
# Out:
#                     Unnamed: 0  0         1             2            3
# 0    (9, 400, np.float64(0.8))  3  0.356250  1.140173e+08  113759764.5
# 1    (7, 390, np.float64(0.8))  3  0.354167  1.097493e+08  109367726.5
# 2    (7, 400, np.float64(0.8))  3  0.354167  1.096464e+08  109472264.0
# 3    (9, 380, np.float64(0.8))  3  0.354167  1.151023e+08  114712632.5
# 4    (9, 390, np.float64(0.8))  3  0.354167  1.148804e+08  114558101.0
# ..                         ... ..       ...           ...          ...
# 589  (1, 360, np.float64(0.9))  3  0.004167  3.837576e+07   37557865.0
# 590  (1, 370, np.float64(0.9))  3  0.004167  3.816661e+07   37634977.0
# 591  (1, 380, np.float64(0.9))  3  0.004167  3.913666e+07   38679857.0
# 592  (1, 390, np.float64(0.9))  3  0.004167  3.969441e+07   39626169.5
# 593  (1, 400, np.float64(0.9))  3  0.004167  3.927863e+07   38871923.5
#
# [594 rows x 5 columns]

# %%
otsu_csv.sort_values("1", ascending= False)
# Out:
#                     Unnamed: 0  0         1             2            3
# 0    (9, 400, np.float64(0.8))  3  0.356250  1.140173e+08  113759764.5
# 3    (9, 380, np.float64(0.8))  3  0.354167  1.151023e+08  114712632.5
# 4    (9, 390, np.float64(0.8))  3  0.354167  1.148804e+08  114558101.0
# 1    (7, 390, np.float64(0.8))  3  0.354167  1.097493e+08  109367726.5
# 2    (7, 400, np.float64(0.8))  3  0.354167  1.096464e+08  109472264.0
# ..                         ... ..       ...           ...          ...
# 589  (1, 360, np.float64(0.9))  3  0.004167  3.837576e+07   37557865.0
# 590  (1, 370, np.float64(0.9))  3  0.004167  3.816661e+07   37634977.0
# 591  (1, 380, np.float64(0.9))  3  0.004167  3.913666e+07   38679857.0
# 592  (1, 390, np.float64(0.9))  3  0.004167  3.969441e+07   39626169.5
# 593  (1, 400, np.float64(0.9))  3  0.004167  3.927863e+07   38871923.5
#
# [594 rows x 5 columns]

# %%
binary_csv.sort_values("1", ascending= False)
# Out:
#                          Unnamed: 0    0         1             2           3
# 885  (1, 390, np.float64(0.8), 170)  0.0  0.883333  3.291389e+07  31922490.5
# 975  (1, 400, np.float64(0.8), 170)  0.0  0.883333  3.279215e+07  31989650.5
# 795  (1, 380, np.float64(0.8), 170)  0.0  0.879167  3.275046e+07  31652262.5
# 705  (1, 370, np.float64(0.8), 170)  0.0  0.875000  3.334838e+07  32128232.5
# 525  (1, 350, np.float64(0.8), 170)  0.0  0.872917  3.316063e+07  32383020.0
# ..                              ...  ...       ...           ...         ...
# 447  (1, 340, np.float64(0.9), 190)  0.0  0.000000  2.838531e+07  26343820.5
# 357  (1, 330, np.float64(0.9), 190)  0.0  0.000000  2.626784e+07  24173206.5
# 269  (1, 320, np.float64(0.9), 210)  0.0  0.000000  1.756510e+07  15866479.5
# 267  (1, 320, np.float64(0.9), 190)  0.0  0.000000  2.765706e+07  25177520.0
# 359  (1, 330, np.float64(0.9), 210)  0.0  0.000000  1.889853e+07  17473790.0
#
# [5940 rows x 5 columns]
